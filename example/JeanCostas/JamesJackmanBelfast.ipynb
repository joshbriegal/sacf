# %%
field = 'NG2152-1403'
test = 'TEST18'
NOI = 101635
obj_id = 17793

# %%
import sys
sys.path.append('/home/jtb34/GACF')
from NGTS.NGTS_Field import NGTSField as Field
from NGTS.NGTS_Object import NGTSObject
import matplotlib.pyplot as plt
import numpy as np

# %%
obj = NGTSObject(field=field, obj=obj_id, test=test)

# %%
obj.get_binned_data()
obj.calculate_periods_from_autocorrelation()
# Out:
# Calculating correlations: 100%|██████████| 2034/2034.0 [00:01<00:00, 1892.04it/s]
# Calculating correlations: 100%|██████████| 1943/1943.0 [00:01<00:00, 1719.94it/s]

# %%
obj.plot_data_autocol_ft(interactive=True)
obj.plot_phase_folded_lcs(interactive=True)
