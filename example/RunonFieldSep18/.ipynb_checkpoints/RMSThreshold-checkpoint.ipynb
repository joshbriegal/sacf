# %%
import sys
import matplotlib.pyplot as plt
# import seaborn as sns
import numpy as np
import scipy as sp
from scipy import stats, integrate
import matplotlib.ticker as tk
import matplotlib as mpl
import os

sys.path.append('/home/jtb34/GitHub/GACF/')
from NGTS.NGTS_Field import return_field_from_object_directory, NGTSField
from NGTS.GACF_utils import TIME_CONVERSIONS, medsig, rebin_err
from NGTS import NGTSObject

from ngtsio import ngtsio

from tqdm import tqdm as tqdm

# %%
FIELDNAME = 'NG0504-3633' 
TEST = 'CYCLE1802'

# %%
n = 50
tdic = ngtsio.get(fieldname=FIELDNAME, ngts_version=TEST, keys=['OBJ_ID'])
nobjs = tdic['OBJ_ID'][:n]
# Out:
# ('Field name:', 'NG0504-3633')
# ('NGTS version:', 'CYCLE1802')
# ('Object IDs (', 6137, '):', array(['000293', '000536', '000542', ..., '030498', '030500', '030501'],
#       dtype='|S6'))
# ###############################################################################
# Success: All keys successfully read into dictionary.
# ###############################################################################

# %%
# GET RMS by finding magnitude and RMS per NGTS LC

dic = ngtsio.get(fieldname=FIELDNAME, ngts_version=TEST, keys=['OBJ_ID', 'FLAGS', 'SYSREM_FLUX3', 'MAG_MEAN', 'BMAG', 'VMAG', 'RMAG', 'JMAG', 'HMAG', 'KMAG'], obj_id=nobjs)
# Out:
# ('Field name:', 'NG0504-3633')
# ('NGTS version:', 'CYCLE1802')
# ('Object IDs (', 50, '):', array(['000293', '000536', '000542', '000550', '000576', '000598',
#        '000637', '000644', '000647', '000652', '000655', '000660',
#        '000674', '000682', '000693', '000704', '000706', '000715',
#        '000717', '000724', '000727', '000735', '000736', '000742',
#        '000746', '000757', '000760', '000765', '000777', '000783',
#        '000785', '000786', '000787', '000794', '000798', '000811',
#        '000817', '000820', '000824', '000825', '000826', '000827',
#        '000833', '000843', '000846', '000849', '000864', '000866',
#        '000869', '000871'], dtype='|S6'))
# ###############################################################################
# Success: All keys successfully read into dictionary.
# ###############################################################################

# %%
XMATCH_LOCATION = '/appch/data/jtb34/{}/cross_match/'.format(FIELDNAME)
FILE_NAME = 'Uncut_Final_{}.fits'.format(FIELDNAME)

from astropy.io import fits

# %%
xmatch_data = fits.open(os.path.join(XMATCH_LOCATION, FILE_NAME))[1]
gaia_mags = xmatch_data.data['Gaia_Gmag']

# %%
data = {}
for i, obj in enumerate(tqdm(dic['OBJ_ID'])):
    flux = dic['SYSREM_FLUX3'][i]
    timeseries = dic['SYSREM_FLUX3'][i]
    
    idx_ok = np.where(dic['FLAGS'][i] == 0)
    flux = flux[idx_ok]
    timeseries = timeseries[idx_ok]
    
    med, sig = medsig(flux)
    flux = flux / med
    
    idx_3_sig = np.where(abs(flux - 1.0) < 3. * sig)
    flux = flux[idx_3_sig] # 3 sigma clipping step
    timeseries = timeseries[idx_3_sig] # 3 sigma clipping step
    try:
        _, flux, _ = rebin_err(timeseries, flux, dt=10.0 * TIME_CONVERSIONS['m2d'])
    except ValueError as e:
        print 'Cannot process object {}'.format(obj)
        print e.message
        continue
    
    med, sig = medsig(flux)
#     mag = dic['MAG_MEAN'][i]
    mag = gaia_mags[i]
    
    data[obj] = {'rms': sig, 'mag': mag}
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# RuntimeWarning: /home/jtb34/python27/ipykernel_launcher.py, line 11
# 	 divide by zero encountered in divide
#
#
# RuntimeWarning: /home/jtb34/python27/ipykernel_launcher.py, line 11
# 	 invalid value encountered in divide
#
#
# RuntimeWarning: /home/jtb34/python27/ipykernel_launcher.py, line 13
# 	 invalid value encountered in less
#
#
# DeprecationWarning: /home/jtb34/python27/ipykernel_launcher.py, line 20
# 	 BaseException.message has been deprecated as of Python 2.6
# Cannot process object 000293
# zero-size array to reduction operation minimum which has no identity
# Cannot process object 000536
# zero-size array to reduction operation minimum which has no identity
# TqdmSynchronisationWarning: /home/jtb34/python27/tqdm/_monitor.py, line 89
# 	 Set changed size during iteration (see https://github.com/tqdm/tqdm/issues/481)
#
#   8%|▊         | 4/50 [00:28<05:24,  7.06s/it]
# Cannot process object 000576
# zero-size array to reduction operation minimum which has no identity
#  12%|█▏        | 6/50 [00:35<04:18,  5.87s/it]
# Cannot process object 000637
# zero-size array to reduction operation minimum which has no identity
# Cannot process object 000644
# zero-size array to reduction operation minimum which has no identity
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-bc5995f7db59> in <module>()
#      15     timeseries = timeseries[idx_3_sig] # 3 sigma clipping step
#      16     try:
# ---> 17         _, flux, _ = rebin_err(timeseries, flux, dt=10.0 * TIME_CONVERSIONS['m2d'])
#      18     except ValueError as e:
#      19         print 'Cannot process object {}'.format(obj)
#
# /home/jtb34/GitHub/GACF/NGTS/GACF_utils/ngtsio_utils.pyc in rebin_err(t, f, dt, get_err_on_mean, bin_about)
#     121     freg_err = np.zeros(nreg) + np.nan
#     122     for i in np.arange(nreg):
# --> 123         l = (t >= treg[i]) * (t < treg[i] + dt)
#     124         if l.any():
#     125             treg[i] = np.nanmean(t[l])
#
# KeyboardInterrupt:

# %%
fig, ax = plt.subplots()
mags = [o['mag'] for o in data.values()]
rms = [o['rms'] for o in data.values()]
# rms = mags[::-1]

ax.scatter(mags, rms, s=0.5)
# ax.set_yscale('log')
# ax.set_ylim([-2, 20])
# ax.set_xlim(15, -10)
plt.show()

# %%
data

# %%
flux = dic['SYSREM_FLUX3'][3]
med, sig = medsig(flux)
print sig
mean = np.nanmean(flux)
idx_ok = np.where(dic['FLAGS'][3] == 0)
flux = flux[idx_ok]
flux = flux / med
flux = flux[np.where((flux - 1.0) < 3 * sig)]
plt.plot(flux, lw=0.1)
# plt.ylim([-100,100])
med, sig = medsig(flux)
print sig

# %%
data

# %%
dic['RMAG']

# %%
from time import time
def rebin_err(t, f, dt=0.02, get_err_on_mean=False, bin_about=None):
    """
    Rebin a time-series with errors on the data (y-points).
    Apply unweighted average: ignore errors on the data to be binned and
                              perform a simple MAD estimation of the error
                              from the scatter of points
    """
    start = time()
    treg = np.r_[t.min():t.max():dt]
    tregtime = time()
    if bin_about is not None:
        treg = np.concatenate([np.r_[bin_about: t.min(): -dt][::-1],
                               np.r_[bin_about + dt: t.max():  dt]])
    concattime = time()
    nreg = len(treg)
    freg = np.zeros(nreg) + np.nan
    freg_err = np.zeros(nreg) + np.nan
    loopstart = time()
    n_data = 0
    for i in np.arange(nreg):
        findstart = time()
        l = (t >= treg[i]) * (t < treg[i] + dt)
        findend = time()
        if l.any():
            n_data += 1
            nanmeanstart = time()
            treg[i] = np.nanmean(t[l])
            nanmeanend = time()
            freg[i], freg_err[i] = medsig(f[l])
            medsigend = time()
            if get_err_on_mean:
                # freg_err[i] /= float(len(f[l]))
                freg_err[i] /= np.sqrt(float(len(f[l])))
        inloopend = time()
    loopend = time()
    l = np.isfinite(freg)
    returntime = time()
    print 'tregtime', tregtime - start
    print 'concattime', concattime - tregtime
    print 'looptime', loopend - loopstart
    print '\t', 'findtime', findend - findstart
    print '\t', 'nanmeantime', nanmeanend - nanmeanstart
    print '\t', 'medsigtime', medsigend - nanmeanend
    print '\t', 'total', inloopend - findstart, '({})'.format((inloopend - findstart) * nreg), nreg
    print 'total', returntime - start
    print 'number of empty times: {} / {}'.format(nreg - n_data, nreg)
    return treg[l], freg[l], freg_err[l]

# %%
i = 49
cleanstart = time()
flux = dic['SYSREM_FLUX3'][i]
timeseries = dic['SYSREM_FLUX3'][i]

idx_ok = np.where(dic['FLAGS'][i] == 0)
flux = flux[idx_ok]
timeseries = timeseries[idx_ok]

med, sig = medsig(flux)
flux = flux / med

idx_3_sig = np.where(abs(flux - 1.0) < 3. * sig)
flux = flux[idx_3_sig] # 3 sigma clipping step
timeseries = timeseries[idx_3_sig] # 3 sigma clipping step
cleanend = time()

print 'cleaning time', cleanend-cleanstart

_, flux, _ = rebin_err(timeseries, flux, dt=10.0 * TIME_CONVERSIONS['m2d'])
# Out:
# RuntimeWarning: /home/jtb34/python27/ipykernel_launcher.py, line 13
# 	 invalid value encountered in less
# cleaning time 0.00929379463196
# tregtime 0.000378847122192
# concattime 0.0
# looptime 8.89866113663
# 	findtime 0.000178813934326
# 	nanmeantime 9.58442687988e-05
# 	medsigtime 0.000205993652344
# 	total 0.000497817993164 (13.0871372223) 26289
# total 8.89914679527
# number of empty times: 13260 / 26289

# %%
def segment_times(timseries, max_gap):
    """
    Returns an N-D arraywhere each row represents a separate segmentation of continuous data with no gaps greater than the max gap.
    """
    time_segments = []
    is_contiguous = False
    arr_n = 0
    for i, t in enumerate(timeseries[:-1]):
        if not is_contiguous:
            time_segments.append([t])
        else:
            time_segments[arr_n].append(t)
        is_contiguous = (timeseries[i+1] - t) < max_gap
    return np.array(time_segments)

# %%
times = segment_times(timeseries, 20.0*TIME_CONVERSIONS['m2d'])

# %%
times
# Out:
# [[9.726160049438477,
#   29.979576110839844,
#   -0.2226075977087021,
#   4.12470006942749,
#   37.21366500854492,
#   37.02836227416992,
#   22.283008575439453,
#   1.7174274921417236,
#   19.108224868774414,
#   7.564174652099609,
#   -1.0994939804077148,
#   30.385351181030273,
#   26.837482452392578,
#   11.838123321533203,
#   5.744938850402832,
#   0.0,
#   17.05173683166504,
#   16.5017147064209,
#   7.653487682342529,
#   15.788463592529297,
#   6.251784801483154,
