# %%
import sys
import matplotlib.pyplot as plt
# import seaborn as sns
import numpy as np
from scipy import stats, integrate
import matplotlib.ticker as tk
import matplotlib as mpl

# %%
sys.path.append('/home/jtb34/GitHub/GACF/')
from NGTS.NGTS_Field import return_field_from_object_directory
from NGTS.GACF_utils import TIME_CONVERSIONS

# %%
#     with open('NG0004-2950/field_reduced.json', 'r') as f:
#         field = return_field_from_json_str(f.read())

field = return_field_from_object_directory('/appch/data/jtb34/NG0004-2950', 'NG0004-2950', test='CYCLE1802')
# Out:
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/101_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/49_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/40_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/48_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/81_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/87_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/72_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/89_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/60_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/94_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/7435_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/4491_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/8202_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/7443_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/2211_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/2213_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/2216_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/5689_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/5690_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/5692_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/8074_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/7397_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/6260_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/3194_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/1922_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/7187_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/6181_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/5959_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/3015_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/8267_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/2294_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/3555_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9095_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/8314_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/8557_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/1918_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/14080_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/12040_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/10129_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/12448_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9748_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/10298_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9784_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9182_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9803_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/12610_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9190_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9785_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9724_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/14702_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/16007_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9909_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9911_VERSION_CYCLE1802
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/15643_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/15400_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/15420_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9435_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/9565_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/12257_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/19985_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/17282_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/19215_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/21017_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/20374_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/18467_VERSION_CYCLE1802
#
#
# UserWarning: /home/jtb34/GitHub/GACF/NGTS/NGTS_Field.py, line 108
# 	 object file not found in /appch/data/jtb34/NG0004-2950/NG0004-2950/18012_VERSION_CYCLE1802
# matched 3574 of 3574 files

# %%
def plot_objects_vs_period(self, calculate=False, signal_to_noise=False, fig_ax_tuple=None,
                               save_if_true_else_return=True, interactive=False,
                               freq=False):
        if calculate:
            self.calculate_periods_from_autocorrelation(calculate_noise=signal_to_noise)
        if fig_ax_tuple is None:
            fig, ax = plt.subplots(figsize=(12, 8))
        else:
            fig, ax = fig_ax_tuple

        max_signal_to_noise = max([max(obj.peak_signal_to_noise) for obj in self if np.array(obj.peak_signal_to_noise).size > 0])
        min_signal_to_noise = min([min(obj.peak_signal_to_noise) for obj in self if np.array(obj.peak_signal_to_noise).size > 0])
        min_obj_id = np.inf
        max_obj_id = 0
        min_p = np.inf
        max_p = -np.inf

        if fig_ax_tuple is None:
            c_min = 1
            c_max = 2  # max_signal_to_noise
            axc = fig.add_axes([0.95, 0.1, 0.01, 0.8])
            norm = mpl.colors.Normalize(vmin=c_min, vmax=c_max)
            cb = mpl.colorbar.ColorbarBase(axc, norm=norm, cmap=mpl.cm.viridis, orientation='vertical')
            cb.set_clim(vmin=c_min, vmax=c_max)
            cb.set_label("Signal to Noise")
        
        for i, obj in enumerate(self):
            if i>50:
                break
            if freq:
                seconds = np.fromiter((x * TIME_CONVERSIONS['d2s'] for x in obj.periods), dtype=np.float64)
                frequencies = np.fromiter((1/x for x in seconds), dtype=np.float64)
                periods = frequencies
            else:
                periods = np.array(obj.periods)
            color = obj.peak_signal_to_noise

            try:
                p_max = periods.max()
                p_min = periods.min()
            except ValueError:
                p_max = np.inf
                p_min = -np.inf
            else:
                if p_max > max_p:
                    max_p = p_max
                if p_min < min_p:
                    min_p = p_min

            obj_id = int(obj.obj)
            if obj_id > max_obj_id:
                max_obj_id = obj_id
            elif obj_id < min_obj_id:
                min_obj_id = obj_id

            if np.array(color).size > 0:
                size = np.interp(color, (min_signal_to_noise, max_signal_to_noise), (0.1, 20))
            else:
                size = color
            y = np.linspace(obj_id, obj_id, len(periods))
            # ax.scatter(periods, y, s=size, c='k')
            ax.scatter(periods, y, c=color, cmap=mpl.cm.viridis, s=size, norm=norm)
            
        if fig_ax_tuple is None:
            ax.set_ylabel('Object no.')
            if freq:
                ax.set_xlabel('Frequency (Hz)')
                
            else:
                ax.set_xlabel('Period (days)')
            ax.set_xscale('log')
            ax.xaxis.grid(True, linestyle='--', alpha=0.5, which='both', lw=1)
            ax.set_xlim([min_p*0.8, max_p + (max_p*0.2)])
            ax.set_ylim([min_obj_id*0.8, max_obj_id + (min_obj_id*0.2)])
            if freq:
                
                def tick_function(freq_locs):
                    period_locs = np.divide(1.0, freq_locs) * TIME_CONVERSIONS['s2d']
                    return ["%.3f" % p for p in period_locs]
                
                fig.suptitle('Objects in NGTSField {} and GACF frequencies'.format(self.fieldname))
                ax.set_xticks(np.linspace(ax.get_xbound()[0], ax.get_xbound()[1], 5))
                ax2 = ax.twiny()
                ax2.set_xlim(ax.get_xlim())
#                 ax2.set_xscale('log')
                freq_locs = ax.get_xticks()
                ax2.set_xticks(freq_locs)
                print freq_locs
                ax2_ticklocs = tick_function(freq_locs)
                print ax2_ticklocs
                ax2.set_xticklabels(ax2_ticklocs)
                ax2.set_xlabel('Period (days)')
            else:
                fig.suptitle('Objects in NGTSField {} and GACF periods'.format(self.fieldname))
            # ax.set_yticks(np.linspace(0, self.num_objects - 1, self.num_objects))
            # ax.set_yticklabels(['obj_id {}'.format(obj.obj) for obj in self], fontdict={'fontsize': 6})

            

            # ax.set_facecolor('lightgray')

            # ax.set_yticks(np.append(ax.get_yticks(), np.linspace(0, self.num_objects - 1, self.num_objects)))
            # ax.set_yticklabels(np.append(ax.get_yticklabels()[1], ['obj_id {}'.format(obj.obj) for obj in self]),
                               # fontdict={'fontsize': 6})

        if save_if_true_else_return:
            if interactive:
                plt.show()
            else:
                if frequencies:
                    fig.savefig(os.path.join(self.filename, 'Objects_vs_Frequency.png'))
                else:
                    fig.savefig(os.path.join(self.filename, 'Objects_vs_Period.png'))
                plt.close(fig)
                return
        else:
            return fig, ax

# %%
plot_objects_vs_period(field, interactive=True, freq=True)
# Out:
# [1.18795711e-07 1.74986167e-05 3.48784377e-05 5.22582587e-05
#  6.96380797e-05]
# ['97.428', '0.661', '0.332', '0.221', '0.166']

# %%
field.plot_objects_vs_period(interactive=True)

# %%
field.plot_objects_vs_period(interactive=True, freq=True)

# %%
all_periods = []
for obj in field:
    all_periods = np.append(all_periods, obj.periods)
    
seconds = np.fromiter((x * 86400. for x in all_periods), dtype=np.float64)
all_freq = np.fromiter((1/x for x in seconds), dtype=np.float64)

# %%
num_bins = 100

# %%
plt.hist(all_freq, bins=num_bins)
plt.show()

# %%
plot_objects_vs_period(field, interactive=True, freq=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-0e218b61531d> in <module>()
# ----> 1 plot_objects_vs_period(field, interactive=True, freq=True)
#
# <ipython-input-33-30e9b4895a15> in plot_objects_vs_period(self, calculate, signal_to_noise, fig_ax_tuple, save_if_true_else_return, interactive, freq)
#      68                 ax2 = ax.twiny()
#      69                 ax2.set_xlim(ax.get_xlim())
# ---> 70                 freq_locs, freq_labels = ax.xticks()
#      71                 period_locs = np.divide(1.0, freq_locs) * TIME_CONVERSIONS['s2d']
#      72                 ax2.set_xticks(period_locs, period_locs)
#
# AttributeError: 'AxesSubplot' object has no attribute 'xticks'

# %%
# sns.set(color_codes=True)
# axp = sns.distplot(all_periods, kde=False, bins=np.logspace(np.log10(1), np.log10(max(all_periods)), num_bins))
# axp.set_xscale('log')
# minor_locator = tk.LogLocator(numticks=20, subs='auto')
# axp.xaxis.set_minor_locator(minor_locator)
# axp.grid(b=True, which='minor', color='w', linewidth=0.5)

# axp.set_ylabel('Count')
# axp.set_xlabel('Period (days)')

# plt.show()

# %%
# seconds = np.fromiter((x * 86400. for x in all_periods), dtype=np.float64)
# frequencies = np.fromiter((1/x for x in seconds), dtype=np.float64)

# %%
# axf = sns.distplot(frequencies, kde=False, bins=np.logspace(np.log10(min(frequencies)), np.log10(max(frequencies)), num_bins))
# axf.set_xscale('log')
# minor_locator = tk.LogLocator(numticks=20, subs='auto')
# axf.xaxis.set_minor_locator(minor_locator)
# axf.grid(b=True, which='minor', color='w', linewidth=0.5)

# axf.set_ylabel('Count')
# axf.set_xlabel('Frequency (Hz)')

# plt.show()

# %%
# %matplotlib
# plt.ion()

# %%
# help(return_field_from_object_directory)
