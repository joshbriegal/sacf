# %%
import time
import numpy as np
from GACF import find_correlation_from_lists

# %%
n_points = 10

# %%
num_data_points = np.logspace(1, 5, n_points, base=10)

# %%
num_data_points = [int(n) for n in num_data_points]

# %%
num_data_points
# Out:
# [10, 27, 77, 215, 599, 1668, 4641, 12915, 35938, 100000]

# %%
num_lag_points = num_data_points

# %%
timings = np.zeros((n_points, n_points))

# %%
for i, N in enumerate(num_data_points):
    for j, M in enumerate(num_lag_points):
        time_series = np.linspace(0, 100, N)
        data = np.sin(time_series)
        max_lag = time_series[-1]
        lag_resolution = float(max_lag) / float(M)
        t_start = time.clock()
        _,_ = find_correlation_from_lists(time_series, data, lag_resolution=lag_resolution, max_lag=max_lag)
        t_end = time.clock()
        run_time = t_end - t_start
        timings[i, j] = run_time
# Out:
# Calculating correlations: 100%|██████████| 11/11.0 [00:00<00:00, 5107.08it/s]
# Calculating correlations:  96%|█████████▋| 27/28.0 [00:00<00:00, 6891.39it/s]
# Calculating correlations:  99%|█████████▊| 77/78.0 [00:00<00:00, 11236.18it/s]
# Calculating correlations: 100%|██████████| 216/216.0 [00:00<00:00, 18848.45it/s]
# Calculating correlations: 100%|██████████| 600/600.0 [00:00<00:00, 15769.94it/s]
# Calculating correlations: 100%|██████████| 1669/1669.0 [00:00<00:00, 26372.31it/s]
# Calculating correlations: 100%|██████████| 4642/4642.0 [00:00<00:00, 34554.90it/s]
# Calculating correlations: 100%|█████████▉| 12915/12916.0 [00:00<00:00, 38199.97it/s]
# Calculating correlations: 100%|██████████| 35939/35939.0 [00:00<00:00, 45297.97it/s]
# Calculating correlations: 100%|█████████▉| 100000/100001.0 [00:02<00:00, 47266.80it/s]
# Calculating correlations: 100%|██████████| 11/11.0 [00:00<00:00, 4170.04it/s]
# Calculating correlations:  96%|█████████▋| 27/28.0 [00:00<00:00, 7278.03it/s]
# Calculating correlations:  99%|█████████▊| 77/78.0 [00:00<00:00, 13616.72it/s]
# Calculating correlations: 100%|██████████| 216/216.0 [00:00<00:00, 11526.18it/s]
# Calculating correlations: 100%|██████████| 600/600.0 [00:00<00:00, 20006.06it/s]
# Calculating correlations: 100%|██████████| 1669/1669.0 [00:00<00:00, 32433.69it/s]
# Calculating correlations: 100%|██████████| 4642/4642.0 [00:00<00:00, 31920.90it/s]
# Calculating correlations: 100%|█████████▉| 12915/12916.0 [00:00<00:00, 36710.16it/s]
# Calculating correlations: 100%|██████████| 35939/35939.0 [00:01<00:00, 33453.75it/s]
# Calculating correlations: 100%|█████████▉| 100000/100001.0 [00:02<00:00, 38192.53it/s]
# Calculating correlations: 100%|██████████| 11/11.0 [00:00<00:00, 3363.76it/s]
# Calculating correlations:  96%|█████████▋| 27/28.0 [00:00<00:00, 5674.51it/s]
# Calculating correlations:  99%|█████████▊| 77/78.0 [00:00<00:00, 5860.41it/s]
# Calculating correlations: 100%|██████████| 216/216.0 [00:00<00:00, 12829.71it/s]
# Calculating correlations: 100%|██████████| 600/600.0 [00:00<00:00, 13623.99it/s]
# Calculating correlations: 100%|██████████| 1669/1669.0 [00:00<00:00, 20729.08it/s]
# Calculating correlations: 100%|██████████| 4642/4642.0 [00:00<00:00, 22013.36it/s]
# Calculating correlations: 100%|█████████▉| 12915/12916.0 [00:00<00:00, 25082.79it/s]
# Calculating correlations: 100%|██████████| 35939/35939.0 [00:01<00:00, 26610.20it/s]
# Calculating correlations: 100%|█████████▉| 100000/100001.0 [00:03<00:00, 27377.79it/s]
# Calculating correlations: 100%|██████████| 11/11.0 [00:00<00:00, 5018.75it/s]
# Calculating correlations:  96%|█████████▋| 27/28.0 [00:00<00:00, 4409.04it/s]
# Calculating correlations:  99%|█████████▊| 77/78.0 [00:00<00:00, 6655.70it/s]
# Calculating correlations: 100%|██████████| 216/216.0 [00:00<00:00, 8473.26it/s]
# Calculating correlations: 100%|██████████| 600/600.0 [00:00<00:00, 10757.52it/s]
# Calculating correlations: 100%|██████████| 1669/1669.0 [00:00<00:00, 12817.65it/s]
# Calculating correlations: 100%|██████████| 4642/4642.0 [00:00<00:00, 11906.08it/s]
# Calculating correlations: 100%|█████████▉| 12915/12916.0 [00:00<00:00, 12960.21it/s]
# Calculating correlations: 100%|██████████| 35939/35939.0 [00:02<00:00, 14070.52it/s]
# Calculating correlations: 100%|█████████▉| 100000/100001.0 [00:07<00:00, 13891.86it/s]
# Calculating correlations: 100%|██████████| 11/11.0 [00:00<00:00, 3944.37it/s]
# Calculating correlations:  96%|█████████▋| 27/28.0 [00:00<00:00, 3049.42it/s]
# Calculating correlations:  99%|█████████▊| 77/78.0 [00:00<00:00, 3392.81it/s]
# Calculating correlations: 100%|██████████| 216/216.0 [00:00<00:00, 3092.47it/s]
# Calculating correlations: 100%|██████████| 600/600.0 [00:00<00:00, 4782.29it/s]
# Calculating correlations: 100%|██████████| 1669/1669.0 [00:00<00:00, 5807.48it/s]
# Calculating correlations: 100%|██████████| 4642/4642.0 [00:00<00:00, 5664.35it/s]
# Calculating correlations: 100%|█████████▉| 12915/12916.0 [00:02<00:00, 5858.05it/s]
# Calculating correlations: 100%|██████████| 35939/35939.0 [00:05<00:00, 6120.93it/s]
# Calculating correlations: 100%|█████████▉| 100000/100001.0 [00:16<00:00, 6038.95it/s]
# Calculating correlations: 100%|██████████| 11/11.0 [00:00<00:00, 1336.73it/s]
# Calculating correlations:  96%|█████████▋| 27/28.0 [00:00<00:00, 1209.74it/s]
# Calculating correlations:  99%|█████████▊| 77/78.0 [00:00<00:00, 1685.52it/s]
# Calculating correlations: 100%|██████████| 216/216.0 [00:00<00:00, 2172.12it/s]
# Calculating correlations: 100%|██████████| 600/600.0 [00:00<00:00, 2329.42it/s]
# Calculating correlations: 100%|██████████| 1669/1669.0 [00:00<00:00, 2211.84it/s]
# Calculating correlations: 100%|██████████| 4642/4642.0 [00:02<00:00, 2281.87it/s]
# Calculating correlations: 100%|█████████▉| 12915/12916.0 [00:05<00:00, 2284.67it/s]
# Calculating correlations: 100%|██████████| 35939/35939.0 [00:15<00:00, 2300.14it/s]
# Calculating correlations: 100%|█████████▉| 100000/100001.0 [00:42<00:00, 2366.70it/s]
# Calculating correlations: 100%|██████████| 11/11.0 [00:00<00:00, 668.41it/s]
# Calculating correlations:  96%|█████████▋| 27/28.0 [00:00<00:00, 705.99it/s]
# Calculating correlations:  99%|█████████▊| 77/78.0 [00:00<00:00, 746.18it/s]
# Calculating correlations: 100%|██████████| 216/216.0 [00:00<00:00, 830.82it/s]
# Calculating correlations: 100%|██████████| 600/600.0 [00:00<00:00, 828.46it/s]
# Calculating correlations: 100%|██████████| 1669/1669.0 [00:01<00:00, 848.52it/s]
# Calculating correlations: 100%|██████████| 4642/4642.0 [00:05<00:00, 880.98it/s]
# Calculating correlations: 100%|█████████▉| 12915/12916.0 [00:14<00:00, 862.67it/s]
# Calculating correlations: 100%|██████████| 35939/35939.0 [00:41<00:00, 863.41it/s]
# Calculating correlations: 100%|█████████▉| 100000/100001.0 [01:55<00:00, 869.42it/s]
# Calculating correlations: 100%|██████████| 11/11.0 [00:00<00:00, 226.60it/s]
# Calculating correlations:  96%|█████████▋| 27/28.0 [00:00<00:00, 272.97it/s]
# Calculating correlations:  99%|█████████▊| 77/78.0 [00:00<00:00, 274.16it/s]
# Calculating correlations: 100%|██████████| 216/216.0 [00:00<00:00, 279.00it/s]
# Calculating correlations: 100%|██████████| 600/600.0 [00:02<00:00, 285.76it/s]
# Calculating correlations: 100%|██████████| 1669/1669.0 [00:05<00:00, 290.93it/s]
# Calculating correlations: 100%|██████████| 4642/4642.0 [00:16<00:00, 290.10it/s]
# Calculating correlations: 100%|█████████▉| 12915/12916.0 [00:43<00:00, 293.57it/s]
# Calculating correlations: 100%|██████████| 35939/35939.0 [02:10<00:00, 274.70it/s]
# Calculating correlations: 100%|█████████▉| 100000/100001.0 [05:38<00:00, 295.55it/s]
# Calculating correlations: 100%|██████████| 11/11.0 [00:00<00:00, 95.87it/s]
# Calculating correlations:  96%|█████████▋| 27/28.0 [00:00<00:00, 95.40it/s]
# Calculating correlations:  99%|█████████▊| 77/78.0 [00:00<00:00, 95.56it/s]
# Calculating correlations: 100%|██████████| 216/216.0 [00:02<00:00, 103.25it/s]
# Calculating correlations: 100%|██████████| 600/600.0 [00:05<00:00, 104.69it/s]
# Calculating correlations: 100%|██████████| 1669/1669.0 [00:16<00:00, 102.95it/s]
# Calculating correlations: 100%|██████████| 4642/4642.0 [00:45<00:00, 102.89it/s]
# Calculating correlations: 100%|█████████▉| 12915/12916.0 [02:04<00:00, 103.74it/s]
# Calculating correlations: 100%|██████████| 35939/35939.0 [06:35<00:00, 90.82it/s]
# Calculating correlations: 100%|█████████▉| 100000/100001.0 [17:10<00:00, 97.03it/s]
# Calculating correlations: 100%|██████████| 11/11.0 [00:00<00:00, 34.34it/s]
# Calculating correlations:  96%|█████████▋| 27/28.0 [00:00<00:00, 32.35it/s]
# Calculating correlations:  99%|█████████▊| 77/78.0 [00:02<00:00, 34.84it/s]
# Calculating correlations: 100%|██████████| 216/216.0 [00:06<00:00, 34.69it/s]
# Calculating correlations: 100%|██████████| 600/600.0 [00:17<00:00, 35.12it/s]
# Calculating correlations: 100%|██████████| 1669/1669.0 [00:50<00:00, 33.25it/s]
# Calculating correlations: 100%|██████████| 4642/4642.0 [02:25<00:00, 31.94it/s]
# Calculating correlations: 100%|█████████▉| 12915/12916.0 [06:26<00:00, 33.46it/s]
# Calculating correlations: 100%|██████████| 35939/35939.0 [17:52<00:00, 33.52it/s]
# Calculating correlations: 100%|█████████▉| 100000/100001.0 [50:31<00:00, 32.99it/s]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from matplotlib.colors import LogNorm
from matplotlib.ticker import LogFormatterMathtext

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = num_data_points
Y = num_lag_points
X, Y = np.meshgrid(X, Y)
# R = np.sqrt(X**2 + Y**2)
# Z = np.sin(R)
Z = timings

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
# ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
X,Y = np.meshgrid(num_data_points, num_lag_points)
Z = timings
im = plt.pcolor(X,Y,Z, cmap='cubehelix', norm=LogNorm())
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Data Points')
plt.ylabel('Number of Lag Steps')

plt.colorbar(im, orientation='vertical',format=LogFormatterMathtext(), label='Run Time / Seconds')
plt.savefig('G-ACF_run_timings.pdf')
plt.show()

# %%
fig, ax = plt.subplots()
for i in range(len(timings)):
    ax.plot(num_lag_points,timings[i], label=str(num_data_points[i])+" data points")
ax.set_ylabel("Time / Seconds")
ax.set_xlabel("Number of Lag Steps")
# ax.legend()
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %%
fig, ax = plt.subplots()
for i in range(len(timings)):
    ax.plot(num_data_points,timings[:,i], label=str(num_lag_points[i])+" lag steps")
ax.set_ylabel("Time / Seconds")
ax.set_xlabel("Number of Data Points")
# ax.legend()
ax.set_yscale('log')
ax.set_xscale('log')
plt.show()

# %%
import os
os.getcwd()
# Out:
# '/Users/joshbriegal/GitHub/GACF/example'

# %%
import pickle

# %%
with open('run_timings.pkl', 'w') as pkl:
    dic = {"lag_steps": num_lag_points, "data_steps": num_data_points, "timings": timings}
    pickle.dump(dic, pkl)

# %%
os.listdir(os.getcwd())
# Out:
# ['.DS_Store',
#  '.ipynb_checkpoints',
#  '__init__.py',
#  'already_processed.txt',
#  'autocorrelation.pdf',
#  'create_field_from_object_files.py',
#  'files',
#  'G-ACF Runtime testing.ipynb',
#  'GACF_utils',
#  'GP_regression_test.py',
#  'increasing_fourier_transform_test.py',
#  'JamesJackmanWork',
#  'misc',
#  'NG0522-2518_031001_LC_tbin=10min.dat',
#  'NG2331-3922',
#  'NGTS_Field.py',
#  'NGTS_Field.pyc',
#  'NGTS_Field_Histogram.ipynb',
#  'NGTS_Field_Histogram.py',
#  'NGTS_GACF_tests.py',
#  'NGTS_Object.py',
#  'NGTS_Object.pyc',
#  'Object_comparison.ipynb',
#  'objects_test_from_file.py',
#  'peaks.log',
#  'period_detections.pkl',
#  'Periods_plot.ipynb',
#  'phase_fold_1.64646_days.pdf',
#  'phase_fold_2.55389652614_days.pdf',
#  'polynomial_fit.py',
#  'processed',
#  'report_plots',
#  'RichardWork',
#  'run_timings.pkl',
#  'scp_temp.pkl',
#  'sine_wave_noise_effects.py',
#  'single_period_sine_wave.py',
#  'Sp1003-0105_5global.csv',
#  'Sp1003-0105_6globalbinned.csv',
#  'temp',
#  'test',
#  'Untitled.ipynb',
#  'Vedad',
#  'Vedad_GACF_comparison.log',
#  'vedad_period_extraction.py']

# %%
with open('run_timings.pkl', 'r') as f:
    timmy = pickle.load(f)

# %%
timmy
# Out:
# {'data_steps': [10, 27, 77, 215, 599, 1668, 4641, 12915, 35938, 100000],
#  'lag_steps': [10, 27, 77, 215, 599, 1668, 4641, 12915, 35938, 100000],
#  'timings': array([[7.06000000e-03, 5.68500000e-03, 8.42300000e-03, 1.46710000e-02,
#          2.94720000e-02, 6.03690000e-02, 1.27725000e-01, 3.02374000e-01,
#          7.98533000e-01, 2.12761300e+00],
#         [5.73300000e-03, 6.09200000e-03, 8.20300000e-03, 1.66480000e-02,
#          3.26920000e-02, 5.78530000e-02, 1.36470000e-01, 3.53022000e-01,
#          1.04288300e+00, 2.63073000e+00],
#         [7.48000000e-03, 6.63300000e-03, 1.20480000e-02, 1.84600000e-02,
#          3.99450000e-02, 8.00740000e-02, 2.02697000e-01, 5.14961000e-01,
#          1.35333700e+00, 3.69852200e+00],
#         [7.40900000e-03, 7.57900000e-03, 1.52400000e-02, 2.75520000e-02,
#          5.86230000e-02, 1.35794000e-01, 3.64206000e-01, 9.58822000e-01,
#          2.55778500e+00, 7.09791700e+00],
#         [9.16000000e-03, 1.17830000e-02, 2.43120000e-02, 5.58240000e-02,
#          1.23932000e-01, 2.85514000e-01, 7.69492000e-01, 2.19198300e+00,
#          5.86637800e+00, 1.65306960e+01],
#         [1.39430000e-02, 2.51940000e-02, 4.85540000e-02, 1.01530000e-01,
#          2.61222000e-01, 7.28733000e-01, 2.00067700e+00, 5.59330300e+00,
#          1.55300320e+01, 4.23055330e+01],
#         [2.52340000e-02, 4.62570000e-02, 1.07966000e-01, 2.57218000e-01,
#          6.98251000e-01, 1.93128300e+00, 5.24044400e+00, 1.49545340e+01,
#          4.15902510e+01, 1.14953385e+02],
#         [6.58230000e-02, 1.13020000e-01, 2.80698000e-01, 7.49646000e-01,
#          2.08286900e+00, 5.69522900e+00, 1.59490490e+01, 4.39112820e+01,
#          1.26818766e+02, 3.36562534e+02],
#         [1.47141000e-01, 3.08909000e-01, 7.97805000e-01, 2.10239500e+00,
#          5.77499500e+00, 1.61514490e+01, 4.48316740e+01, 1.24262986e+02,
#          3.76661337e+02, 1.00551504e+03],
#         [4.12914000e-01, 8.81735000e-01, 2.29272200e+00, 6.24256600e+00,
#          1.70574240e+01, 4.88376660e+01, 1.38882117e+02, 3.78205485e+02,
#          1.05450979e+03, 2.96124496e+03]])}

# %%
plt.scatter(num_lag_points, timings[9])
plt.show()
